# %%
import pandas as pd

df = pd.read_csv (r"C:\Users\Junaid\Desktop\python_with_junaid\our_data_chilla\Chilla_data.csv")
df.head()
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
# 4  Female  Pakistan  26-30                 Masters       Enginnering
#
#          Purpose_for_chilla What are you? Blood group   \
# 0     to boost my skill set     Unemplyed           B+
# 1     to boost my skill set       Student           B+
# 2  Switch my field of study      Employed           B+
# 3     to boost my skill set      Employed           O+
# 4     to boost my skill set       Student           A-
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
# ...

# %%
import plotly.express as px
import pandas as pd
df = pd.read_csv (r"C:\Users\Junaid\Desktop\python_with_junaid\our_data_chilla\Chilla_data.csv")
fig = px.scatter(df, x="Age", y="Gender", color="Marital Status?", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\plotly\express\_core.py in make_trace_kwargs(args, trace_spec, trace_data, mapping_labels, sizeref)
#     333                         try:
# --> 334                             x = x.astype(np.float64)
#     335                         except ValueError:
#
# ValueError: could not convert string to float: '16-20'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6344/1694017302.py in <module>
#       2 import pandas as pd
#       3 df = pd.read_csv (r"C:\Users\Junaid\Desktop\python_with_junaid\our_data_chilla\Chilla_data.csv")
# ----> 4 fig = px.scatter(df, x="Age", y="Gender", color="Marital Status?", marginal_y="violin",
# ...
